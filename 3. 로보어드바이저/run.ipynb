# %%
from red.red import RED
from red.portfolio import Portfolio

# %%
RED().run()
# Out:
# 입력이 완료되었습니다, 투자자 성향을 판단중입니다
# ···
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=613x677 at 0x1B66AE183C8>
# 추천 주식 종목 찾는 중...
# 추천 ETF 찾는 중...
#
#
# 고객님의 포트폴리오입니다.
#
#
# 주식 종목 : 598735.0원
#
# 제이앤티씨, 3개 매입. long_candle 전략. 현재가: 11500.0
# 한솔케미칼, 1개 매입. long_candle 전략. 현재가: 196500.0
# 원익IPS, 1개 매입. g 전략. 현재가: 44300.0
# 한국테크놀로지그룹, 1개 매입. rsi_sto 전략. 현재가: 14650.0
# 하나머티리얼즈, 1개 매입. long_candle 전략. 현재가: 28550.0
# 파크시스템스, 1개 매입. long_candle 전략. 현재가: 95800.0
# 레고켐바이오, 1개 매입. g 전략. 현재가: 70600.0
# GS건설, 2개 매입. g 전략. 현재가: 37700.0
# 유진테크, 1개 매입. g 전략. 현재가: 33450.0
# 대우건설, 1개 매입. long_candle 전략. 현재가: 4985.0
#
# 채권 ETF 종목 : 0.0원
#
#
# 일반 ETF 종목 : 399450.0원
#
# KODEX 바이오, 5개 매입. 20일 후 리밸런싱 권장. 현재가: 17060.0
# TIGER 현대차그룹+펀더멘털, 5개 매입. 20일 후 리밸런싱 권장. 현재가: 22030.0
# KODEX 자동차, 4개 매입. 20일 후 리밸런싱 권장. 현재가: 19485.0
# KODEX 2차전지산업, 4개 매입. 20일 후 리밸런싱 권장. 현재가: 15620.0
# KBSTAR 200IT, 4개 매입. 20일 후 리밸런싱 권장. 현재가: 15895.0
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1073x523 at 0x1B666F054C8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1068x77 at 0x1B66A428B08>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1065x523 at 0x1B66AB61A08>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1065x523 at 0x1B66B5BA0C8>
# Button(description='결과 저장', style=ButtonStyle())

# %%
Portfolio().calculate_return()

# %%
import Industry_Analysis as Industry
Industry.industry_analysis()
# Out:
# 산업간 양(+)의 상관관계가 총 1개 발견되었습니다.
#
# 산업간 음(-)의 상관관계가 총 3개 발견되었습니다.

# %%
import pandas as pd
tmp  = pd.read_csv('./data/users/userDB.csv',encoding='cp949', index_col = 0)
tmp
# Out:
#    투자 금액(만 원)      투자 기간  나이 성별  월 정기 수입(만 원) 관심산업분야  \
# 0         100   1주 ~ 1개월  24  남           0.0     IT
# 1          50  1개월 ~ 6개월  24  남           0.0     IT
# 2          30  1개월 ~ 6개월  24  남           0.0     유통
# 3          30  1개월 ~ 6개월  26  남          65.0     의약
# 4         500   6개월 ~ 1년  25  남           0.0     화학
# 5         300   1주 ~ 1개월  20  남         100.0     건설
# 6        1000   6개월 ~ 1년  25  남         100.0     IT
# 7       10000  1개월 ~ 6개월  25  남        1000.0     의약
# 8          10   1주 ~ 1개월  20  남         100.0     의약
#
#                                               금융지식수준  \
# 0  널리 알려진 금융투자 상품(주식, 채권 및 펀드 등)의 구조 및 위험을 깊이 있게 ...
# 1  널리 알려진 금융투자 상품(주식, 채권 및 펀드 등)의 구조 및 위험을 일정 부분 ...
# 2  널리 알려진 금융투자 상품(주식, 채권 및 펀드 등)의 구조 및 위험을 일정 부분 ...
# 3                               금융투자상품에 투자해 본 경험이 없음
# 4            파생상품을 포함한 대부분의 금융투자상품의 구조 및 위험을 이해하고 있음
# 5                               금융투자상품에 투자해 본 경험이 없음
# 6                               금융투자상품에 투자해 본 경험이 없음
# 7  널리 알려진 금융투자 상품(주식, 채권 및 펀드 등)의 구조 및 위험을 깊이 있게 ...
# 8                               금융투자상품에 투자해 본 경험이 없음
#
#                                               위험추구성향  \
# 0  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 1  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 2  투자원금의 손실 위험을 최소화하고, 안정적인 투자를 목표 / 예금ㆍ적금보다 높은 수...
# 3  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 4  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 5            예금 또는 적금 수준의 수익률을 기대 / 투자원금의 손실을 원하지 않음
# 6  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 7  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 8  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
#
#                                                   주식  \
# 0  [('DB하이텍', [1, [42950.0, 'long_candle', 2.16, ...
# 1  [('DB하이텍', [1, [42950.0, 'long_candle', 2.16, ...
# 2  [('DB하이텍', [1, [42950.0, 'long_candle', 2.16, ...
# 3  [('DB하이텍', [1, [42950.0, 'long_candle', 2.16, ...
# 4  [('DB하이텍', [5, [42950.0, 'long_candle', 2.16, ...
# 5                                                 []
# 6  [('씨젠', [4, [199000.0, 'long_candle', 2.16, 0....
# 7  [('씨젠', [38, [199000.0, 'long_candle', 2.16, 0...
# 8  [('원익IPS', [1, [44350.0, 'g', 2.1, 0.028857819...
#
#                                                   채권  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [('TIGER 단기선진하이일드(합성 H)', [3, [12045.0, 0.1100...
# 5                                                 []
# 6  [('TIGER 단기선진하이일드(합성 H)', [6, [12050.0, 0.1100...
# 7                                                 []
# 8                                                 []
#
#                                                  ETF          날짜  현재 수익률(%)  \
# 0  [('KBSTAR 200IT', [5, [14825.0, 0.67, 1.21, 0....  2020-12-26       5.13
# 1  [('KBSTAR 200IT', [3, [14825.0, 0.67, 1.21, 0....  2020-12-26       6.55
# 2  [('KBSTAR 200경기소비재', [4, [10015.0, 0.59, 1.21,...  2020-12-26       5.79
# 3  [('KBSTAR 헬스케어', [2, [18395.0, 0.56, 1.21, 0.0...  2020-12-26       7.25
# 4  [('KODEX 에너지화학', [18, [16255.0, 0.81, 1.21, 0....  2020-12-26       4.33
# 5  [('TIGER 200 건설', [43, [2380.0, 0.45, 1.21, 0....  2020-12-29       1.40
# 6  [('TIGER 200 IT', [28, [34685.0, 0.75, 1.21, 0...  2020-12-29       0.24
# 7  [('KBSTAR 헬스케어', [435, [19090.0, 0.62, 1.21, 0...  2020-12-29       0.20
# 8  [('KODEX 바이오', [1, [17100.0, 0.64, 1.21, 0.022...  2020-12-30       0.00
#
#     수익률 기준 날짜
# 0  20201230.0
# 1  20201230.0
# 2  20201230.0
# 3  20201230.0
# 4  20201230.0
# 5  20201230.0
# 6  20201230.0
# 7  20201230.0
# 8  20201230.0
